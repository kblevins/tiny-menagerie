# %%
import datetime as dt
import numpy as np
import pandas as pd
import json

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
engine = create_engine("sqlite:///data/belly_button_biodiversity.sqlite", echo=False)

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['otu', 'samples', 'samples_metadata']

# %%
#################################################
# Database Setup
#################################################

# Reflect Database into ORM class
Base = automap_base()
Base.prepare(engine, reflect=True)
OTU = Base.classes.otu
Samples = Base.classes.samples
Meta = Base.classes.samples_metadata

# %%
def sample_list():
    columns = inspector.get_columns('samples')
    sample_ids = []
    for c in columns:
        sample_ids.append(c['name'])
    sample_ids = sample_ids[1:]
    return sample_ids

# %%
sample_ids = sample_list()
sample_ids[0:10]
# Out:
# ['BB_940',
#  'BB_941',
#  'BB_943',
#  'BB_944',
#  'BB_945',
#  'BB_946',
#  'BB_947',
#  'BB_948',
#  'BB_949',
#  'BB_950']

# %%
session = Session(engine)

# %%
# create a list of otu descriptions
def otu_list():
    results = session.query(OTU.lowest_taxonomic_unit_found).all()
    return results

# %%
otus = otu_list()
otus[0:5]
# Out:
# [('Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Halobacteriaceae;Halococcus'),
#  ('Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Halobacteriaceae;Halococcus'),
#  ('Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Halobacteriaceae;Natronorubrum'),
#  ('Archaea;Euryarchaeota;Methanobacteria;Methanobacteriales;Methanobacteriaceae;Methanobrevibacter'),
#  ('Archaea;Euryarchaeota;Methanobacteria;Methanobacteriales;Methanobacteriaceae;Methanobrevibacter')]

# %%
def return_metadata(sample):

    sample = sample.replace("BB_", "")
    sample = int(sample)
    met = session.query(Meta.AGE, Meta.BBTYPE, Meta.ETHNICITY, Meta.GENDER,\
                             Meta.LOCATION, Meta.SAMPLEID).filter(Meta.SAMPLEID == sample).all()
    cols = ('AGE', 'BBTYPE', 'ETHNICITY', 'GENDER', 'LOCATION', 'SAMPLEID')
    samp_dict = {}
    for i in range(0,len(met[0])):
        samp_dict[cols[i]] = met[0][i]
    
    return json.dumps(samp_dict)

# %%
return_metadata("BB_940")
# Out:
# '{"AGE": 24, "BBTYPE": "I", "ETHNICITY": "Caucasian", "GENDER": "F", "LOCATION": "Beaufort/NC", "SAMPLEID": 940}'

# %%
def return_metadata(sample):

    sample = sample.replace("BB_", "")
    sample = int(sample)
    wash = session.query(Meta.WFREQ).filter(Meta.SAMPLEID == sample).all()
   
    return wash[0][0]

# %%
return_metadata("BB_940")
# Out:
# 2

# %%
def otu_df(sample):
    col = f'Samples.{sample}'
    zoo = session.query(Samples.otu_id, col).all()
    zoo_df = pd.DataFrame(zoo)
    zoo_df.columns = ['otu_id', 'sample_value']
    zoo_df = zoo_df.sort_values('sample_value', ascending = False)
    return zoo_df

# %%
otu_df("BB_940").head(10)
# Out:
#       otu_id  sample_value
# 1166    1167           163
# 2858    2859           126
# 481      482           113
# 2263    2264            78
# 40        41            71
# 1188    1189            51
# 351      352            50
# 188      189            47
# 2317    2318            40
# 1976    1977            40

# %%
bb_940 = otu_df("BB_940")

# %%
def otu_list():
    results = session.query(OTU.otu_id, OTU.lowest_taxonomic_unit_found).all()
    return results
otu_df = pd.DataFrame(otu_list())
otu_df.head()
# Out:
#    otu_id                        lowest_taxonomic_unit_found
# 0       1  Archaea;Euryarchaeota;Halobacteria;Halobacteri...
# 1       2  Archaea;Euryarchaeota;Halobacteria;Halobacteri...
# 2       3  Archaea;Euryarchaeota;Halobacteria;Halobacteri...
# 3       4  Archaea;Euryarchaeota;Methanobacteria;Methanob...
# 4       5  Archaea;Euryarchaeota;Methanobacteria;Methanob...

# %%
otu_df.loc[otu_df['otu_id'] ==  3645,]
# Out:
#       otu_id                        lowest_taxonomic_unit_found
# 3644    3645  Bacteria;Synergistetes;Synergistia;Synergistal...

# %%
bb_940_wn = pd.merge(bb_940, otu_df)

# %%
sample = "BB_940"
col = f'Samples.{sample}'
zoo = session.query(Samples.otu_id, col).all()
zoo_df = pd.DataFrame(zoo)
zoo_df.columns = ['otu_id', 'sample_value']
zoo_df = zoo_df.sort_values('sample_value', ascending = False)
zoo_df.head()
# Out:
#       otu_id  sample_value
# 1166    1167           163
# 2858    2859           126
# 481      482           113
# 2263    2264            78
# 40        41            71

# %%
otu_list = session.query(OTU.otu_id, OTU.lowest_taxonomic_unit_found).all()
otu_df = pd.DataFrame(otu_list)
otu_df.head()
# Out:
#    otu_id                        lowest_taxonomic_unit_found
# 0       1  Archaea;Euryarchaeota;Halobacteria;Halobacteri...
# 1       2  Archaea;Euryarchaeota;Halobacteria;Halobacteri...
# 2       3  Archaea;Euryarchaeota;Halobacteria;Halobacteri...
# 3       4  Archaea;Euryarchaeota;Methanobacteria;Methanob...
# 4       5  Archaea;Euryarchaeota;Methanobacteria;Methanob...

# %%
zoo_df_wn = pd.merge(zoo_df, otu_df)
zoo_df_j = zoo_df_wn.to_json(orient="records")
zoo_df_j
# Out:
# '[{"otu_id":1167,"sample_value":163,"lowest_taxonomic_unit_found":"Bacteria;Bacteroidetes;Bacteroidia;Bacteroidales;Porphyromonadaceae;Porphyromonas"},{"otu_id":2859,"sample_value":126,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI;Peptoniphilus"},{"otu_id":482,"sample_value":113,"lowest_taxonomic_unit_found":"Bacteria"},{"otu_id":2264,"sample_value":78,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI"},{"otu_id":41,"sample_value":71,"lowest_taxonomic_unit_found":"Bacteria"},{"otu_id":1189,"sample_value":51,"lowest_taxonomic_unit_found":"Bacteria;Bacteroidetes;Bacteroidia;Bacteroidales;Porphyromonadaceae;Porphyromonas"},{"otu_id":352,"sample_value":50,"lowest_taxonomic_unit_found":"Bacteria"},{"otu_id":189,"sample_value":47,"lowest_taxonomic_unit_found":"Bacteria"},{"otu_id":2318,"sample_value":40,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI;Anaerococcus"},{"otu_id":1977,"sample_value":40,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales"},{"otu_id":3450,"sample_value":37,"lowest_taxonomic_unit_found":"Bacteria;Proteobacteria;Epsilonproteobacteria;Campylobacterales;Campylobacteraceae;Campylobacter"},{"otu_id":874,"sample_value":36,"lowest_taxonomic_unit_found":"Bacteria;Actinobacteria;Actinobacteria;Actinomycetales;Actinomycetaceae;Varibaculum"},{"otu_id":1959,"sample_value":30,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia"},{"otu_id":2191,"sample_value":28,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI"},{"otu_id":1950,"sample_value":25,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia"},{"otu_id":2077,"sample_value":23,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales"},{"otu_id":2275,"sample_value":22,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI"},{"otu_id":944,"sample_value":19,"lowest_taxonomic_unit_found":"Bacteria;Actinobacteria;Actinobacteria;Actinomycetales;Corynebacteriaceae;Corynebacterium"},{"otu_id":2184,"sample_value":19,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI"},{"otu_id":2244,"sample_value":14,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI"},{"otu_id":2024,"sample_value":13,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales"},{"otu_id":2811,"sample_value":13,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI;Peptoniphilus"},{"otu_id":2419,"sample_value":13,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI;Anaerococcus"},{"otu_id":2782,"sample_value":12,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI;Peptoniphilus"},{"otu_id":165,"sample_value":12,"lowest_taxonomic_unit_found":"Bacteria"},{"otu_id":2011,"sample_value":11,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales"},{"otu_id":2247,"sample_value":11,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI"},{"otu_id":2396,"sample_value":11,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI;Anaerococcus"},{"otu_id":2964,"sample_value":10,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;Veillonellaceae"},{"otu_id":830,"sample_value":10,"lowest_taxonomic_unit_found":"Bacteria;Actinobacteria;Actinobacteria;Actinomycetales"},{"otu_id":1795,"sample_value":10,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Bacilli;Bacillales;Staphylococcaceae;Staphylococcus"},{"otu_id":2722,"sample_value":8,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clostridiales;IncertaeSedisXI;Finegoldia"},{"otu_id":2178,"sample_value":7,"lowest_taxonomic_unit_found":"Bacteria;Firmicutes;Clostridia;Clos ...

# %%
#bb_940_wn.to_json("BB_940_otu_df.json", orient="records")
